# %% [markdown]
# ## Earth Pressure Report
#
# This notebook correlates global pressure signals
# with ethical stress inside HMN.

# %%
## Load pressure signals
from collections import pd

pressure = pd.read_csv("earth_pressure.csv")
pressure.head()

# %%
## Correlation
pressure.corr()

# %% [markdown]
# ### Interpretation
#
# - Are agents overloaded?
# - Is moral fatigue increasing?
# - Should the system slow down globally?
#
# Human judgment required here.
